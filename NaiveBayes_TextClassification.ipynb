# %% [markdown]
# <a href="https://colab.research.google.com/github/ashmina-ashraf/DataScience/blob/main/NaiveBayes_TextClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import mnist
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
import seaborn as sns

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)

# %%
gnb = GaussianNB()
nb_model = gnb.fit(x_train, y_train)
y_pred = nb_model.predict(x_test)

# %%
accuracy = metrics.accuracy_score(y_pred, y_test)
print(accuracy)
# Out:
# 0.5558

# %%
print(metrics.confusion_matrix(y_pred, y_test))
# Out:
# [[ 870    0   79   32   19   71   12    0   13    5]
#  [   0 1079   25   39    2   25   12   15   72    7]
#  [   3    2  266    6    5    1    3    2    3    3]
#  [   5    1   91  353    4   20    1   10    7    6]
#  [   2    0    5    2  168    3    1    5    3    1]
#  [   5    0    2    3    7   44    7    1   11    0]
#  [  31   10  269   51   63   40  895    5   12    1]
#  [   1    0    4    8    7    2    0  280    4   13]
#  [  35   38  271  409  210  586   26   39  648   18]
#  [  28    5   20  107  497  100    1  671  201  955]]

# %%
f, ax = plt.subplots(figsize=(10,10))
sns.heatmap(metrics.confusion_matrix(y_test, y_pred),annot=True, linecolor='white')
